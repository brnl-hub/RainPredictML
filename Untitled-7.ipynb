# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Extracted-dataset.csv')
dataset.head()
# Out:
#          Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0  2009-01-01  NorfolkIsland     20.4     25.8       0.0          6.0
# 1  2009-01-02  NorfolkIsland     20.9     26.7       0.2          8.0
# 2  2009-01-03  NorfolkIsland     22.3     26.3       0.0          3.2
# 3  2009-01-04  NorfolkIsland     21.6     22.2       1.2          2.8
# 4  2009-01-05  NorfolkIsland     20.4     23.5       2.6          2.2
#
#    Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0      12.4         NNW           31.0        NNW  ...        71.0
# 1      10.3           N           31.0        NNE  ...        77.0
# 2       2.0           E           35.0        ENE  ...        90.0
# 3       0.0         ESE           41.0        ESE  ...        95.0
# 4       2.9         ESE           52.0        ESE  ...        86.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1014.5       1013.6       3.0       1.0     23.3     24.7         No
# 1       1016.3       1015.5       2.0       5.0     25.0     25.1         No
# 2       1014.6       1014.3       7.0       7.0     24.7     23.8         No
# 3       1016.0       1015.3       8.0       8.0     22.1     21.2        Yes
# 4       1015.3       1013.7       7.0       7.0     21.8     21.6        Yes
#
#    RISK_MM  RainTomorrow
# 0      0.2            No
# 1      0.0            No
# 2      1.2           Yes
# 3      2.6           Yes
# 4      0.0            No
#
# [5 rows x 24 columns]

# %% [markdown]
# Data Exploration and preprocessing

# %%
dataset.shape
# Out:
# (121575, 24)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121575 entries, 0 to 121574
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           121575 non-null  object
#  1   Location       121575 non-null  object
#  2   MinTemp        121260 non-null  float64
#  3   MaxTemp        121429 non-null  float64
#  4   Rainfall       120391 non-null  float64
#  5   Evaporation    74674 non-null   float64
#  6   Sunshine       70283 non-null   float64
#  7   WindGustDir    115654 non-null  object
#  8   WindGustSpeed  115713 non-null  float64
#  9   WindDir9am     114342 non-null  object
#  10  WindDir3pm     119492 non-null  object
#  11  WindSpeed9am   120767 non-null  float64
#  12  WindSpeed3pm   120162 non-null  float64
#  13  Humidity9am    120156 non-null  float64
#  14  Humidity3pm    119011 non-null  float64
#  15  Pressure9am    110963 non-null  float64
#  16  Pressure3pm    111001 non-null  float64
#  17  Cloud9am       77303 non-null   float64
#  18  Cloud3pm       74190 non-null   float64
#  19  Temp9am        120892 non-null  float64
#  20  Temp3pm        119755 non-null  float64
#  21  RainToday      120391 non-null  object
#  22  RISK_MM        121575 non-null  float64
#  23  RainTomorrow   121575 non-null  object
# dtypes: float64(17), object(7)
# memory usage: 22.3+ MB

# %%
print('RainToday' in dataset.columns)
# Out:
# True

# %%
dataset['RainToday'].replace({'No': 0, 'Yes': 1}, inplace=True)
dataset['RainTomorrow'].replace({'No': 0, 'Yes': 1}, inplace=True)
dataset.head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25748\3022014587.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['RainToday'].replace({'No': 0, 'Yes': 1}, inplace=True)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25748\3022014587.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset['RainToday'].replace({'No': 0, 'Yes': 1}, inplace=True)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25748\3022014587.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['RainTomorrow'].replace({'No': 0, 'Yes': 1}, inplace=True)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25748\3022014587.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset['RainTomorrow'].replace({'No': 0, 'Yes': 1}, inplace=True)
#          Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0  2009-01-01  NorfolkIsland     20.4     25.8       0.0          6.0
# 1  2009-01-02  NorfolkIsland     20.9     26.7       0.2          8.0
# 2  2009-01-03  NorfolkIsland     22.3     26.3       0.0          3.2
# 3  2009-01-04  NorfolkIsland     21.6     22.2       1.2          2.8
# 4  2009-01-05  NorfolkIsland     20.4     23.5       2.6          2.2
#
#    Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0      12.4         NNW           31.0        NNW  ...        71.0
# 1      10.3           N           31.0        NNE  ...        77.0
# 2       2.0           E           35.0        ENE  ...        90.0
# 3       0.0         ESE           41.0        ESE  ...        95.0
# 4       2.9         ESE           52.0        ESE  ...        86.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1014.5       1013.6       3.0       1.0     23.3     24.7        0.0
# 1       1016.3       1015.5       2.0       5.0     25.0     25.1        0.0
# 2       1014.6       1014.3       7.0       7.0     24.7     23.8        0.0
# 3       1016.0       1015.3       8.0       8.0     22.1     21.2        1.0
# 4       1015.3       1013.7       7.0       7.0     21.8     21.6        1.0
#
#    RISK_MM  RainTomorrow
# 0      0.2             0
# 1      0.0             0
# 2      1.2             1
# 3      2.6             1
# 4      0.0             0
#
# [5 rows x 24 columns]

# %%
numeric_df = dataset.select_dtypes(include=['float64', 'int64'])

#  Compute Pearson correlation with 'RainTomorrow'
correlation_with_target = numeric_df.corr()['RainTomorrow'].sort_values(ascending=False)

correlation_with_target
# Out:
# RainTomorrow     1.000000
# RISK_MM          0.502849
# Humidity3pm      0.442813
# Cloud3pm         0.377486
# RainToday        0.313772
# Cloud9am         0.309105
# Humidity9am      0.252393
# Rainfall         0.241102
# WindGustSpeed    0.233864
# WindSpeed9am     0.091727
# WindSpeed3pm     0.090014
# MinTemp          0.073508
# Temp9am         -0.031605
# Evaporation     -0.122722
# MaxTemp         -0.163603
# Temp3pm         -0.195848
# Pressure3pm     -0.242843
# Pressure9am     -0.262722
# Sunshine        -0.445487
# Name: RainTomorrow, dtype: float64

# %%
sns.barplot(
    x=correlation_with_target.values,
    y=correlation_with_target.index                #  .index gives us the row labels — which, in this case, are the names of the featu
)
# Out:
# <Axes: ylabel='None'>

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (8,5))
dataset.RainTomorrow.value_counts(normalize = True).plot(kind='bar', color= ['skyblue','navy'], alpha = 0.9, rot=0)  
plt.title('RainTomorrow Indicator No(0) and Yes(1) in the Imbalanced Dataset')
plt.show()

# %%
sns.heatmap(dataset.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
# Out:
# Text(0.5, 1.0, 'Missing Values Heatmap')

# %% [markdown]
# Data preprocessing and cleaning

# %% [markdown]
#       (i) Handling class imbalance usinng oversampling

# %%
print("Before oversampling:", dataset.shape)
# Out:
# Before oversampling: (121575, 24)

# %%
from sklearn.utils import resample

no = dataset[dataset.RainTomorrow == 0]
yes = dataset[dataset.RainTomorrow == 1]
yes_oversampled = resample(yes, replace=True, n_samples=len(no), random_state=123)
oversampled = pd.concat([no, yes_oversampled])

fig = plt.figure(figsize = (8,5))
oversampled.RainTomorrow.value_counts(normalize = True).plot(kind='bar', color= ['skyblue','navy'], alpha = 0.9, rot=0)
plt.title('RainTomorrow Indicator No(0) and Yes(1) after Oversampling (Balanced Dataset)')
plt.show()

# %%
sns.heatmap(dataset.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
# Out:
# Text(0.5, 1.0, 'Missing Values Heatmap')

# %%
total = oversampled.isnull().sum().sort_values(ascending=False)
percent = (oversampled.isnull().sum()/oversampled.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head(4)
# Out:
#              Total   Percent
# Sunshine     79040  0.420037
# Evaporation  73016  0.388024
# Cloud3pm     70947  0.377029
# Cloud9am     67253  0.357398

# %% [markdown]
#     (ii) Imputation and Transformation

# %%
oversampled.select_dtypes(include=['object']).columns
# Out:
# Index(['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'], dtype='object')

# %%
# Impute categorical var with Mode
oversampled['Date'] = oversampled['Date'].fillna(oversampled['Date'].mode()[0])
oversampled['Location'] = oversampled['Location'].fillna(oversampled['Location'].mode()[0])
oversampled['WindGustDir'] = oversampled['WindGustDir'].fillna(oversampled['WindGustDir'].mode()[0])
oversampled['WindDir9am'] = oversampled['WindDir9am'].fillna(oversampled['WindDir9am'].mode()[0])
oversampled['WindDir3pm'] = oversampled['WindDir3pm'].fillna(oversampled['WindDir3pm'].mode()[0])

# %%
# Convert categorical features to continuous features with Label Encoding
from sklearn.preprocessing import LabelEncoder
lencoders = {}
for col in oversampled.select_dtypes(include=['object']).columns:
    lencoders[col] = LabelEncoder()
    oversampled[col] = lencoders[col].fit_transform(oversampled[col])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Multiple Imputation by Chained Equations
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
MiceImputed = oversampled.copy(deep=True) 
mice_imputer = IterativeImputer()
MiceImputed.iloc[:, :] = mice_imputer.fit_transform(oversampled)

# %%
MiceImputed.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   426        20     20.4     25.8       0.0          6.0      12.4
# 1   427        20     20.9     26.7       0.2          8.0      10.3
# 4   430        20     20.4     23.5       2.6          2.2       2.9
# 5   431        20     20.4     24.4       0.0          3.0       8.7
# 6   432        20     20.2     24.2       0.0          7.2       6.0
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity3pm  Pressure9am  \
# 0            6           31.0           6  ...         71.0       1014.5
# 1            3           31.0           5  ...         77.0       1016.3
# 4            2           52.0           2  ...         86.0       1015.3
# 5            0           48.0           2  ...         79.0       1014.5
# 6            2           52.0           2  ...         79.0       1014.1
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1013.6       3.0       1.0     23.3     24.7        0.0      0.2
# 1       1015.5       2.0       5.0     25.0     25.1        0.0      0.0
# 4       1013.7       7.0       7.0     21.8     21.6        1.0      0.0
# 5       1012.7       5.0       3.0     21.4     23.3        0.0      0.0
# 6       1013.0       6.0       2.0     21.9     23.3        0.0      0.0
#
#    RainTomorrow
# 0             0
# 1             0
# 4             0
# 5             0
# 6             0
#
# [5 rows x 24 columns]

# %%
MiceImputed.isna()
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       False     False    False    False     False        False     False
# 1       False     False    False    False     False        False     False
# 4       False     False    False    False     False        False     False
# 5       False     False    False    False     False        False     False
# 6       False     False    False    False     False        False     False
# ...       ...       ...      ...      ...       ...          ...       ...
# 107777  False     False    False    False     False        False     False
# 39626   False     False    False    False     False        False     False
# 98175   False     False    False    False     False        False     False
# 22326   False     False    False    False     False        False     False
# 67990   False     False    False    False     False        False     False
#
#         WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity3pm  Pressure9am  \
# 0             False          False       False  ...        False        False
# 1             False          False       False  ...        False        False
# 4             False          False       False  ...        False        False
# 5             False          False       False  ...        False        False
# 6             False          False       False  ...        False        False
# ...             ...            ...         ...  ...          ...          ...
# 107777        False          False       False  ...        False        False
# 39626         False          False       False  ...        False        False
# 98175         False          False       False  ...        False        False
# 22326         False          False       False  ...        False        False
# 67990         False          False       False  ...        False        False
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0             False     False     False    False    False      False    False
# 1             False     False     False    False    False      False    False
# 4             False     False     False    False    False      False    False
# 5             False     False     False    False    False      False    False
# 6             False     False     False    False    False      False    False
# ...             ...       ...       ...      ...      ...        ...      ...
# 107777        False     False     False    False    False      False    False
# 39626         False     False     False    False    False      False    False
# 98175         False     False     False    False    False      False    False
# 22326         False     False     False    False    False      False    False
# 67990         False     False     False    False    False      False    False
#
#         RainTomorrow
# 0              False
# 1              False
# 4              False
# 5              False
# 6              False
# ...              ...
# 107777         False
# 39626          False
# 98175          False
# 22326          False
# 67990          False
#
# [188174 rows x 24 columns]

# %% [markdown]
#     (iii)  Detecting outliers with Inter Quartile Range

# %%
Q1 = MiceImputed.quantile(0.25)
Q3 = MiceImputed.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Date             1538.750000
# Location           21.000000
# MinTemp             9.200000
# MaxTemp            10.500000
# Rainfall            2.400000
# Evaporation         4.183058
# Sunshine            5.961061
# WindGustDir         9.000000
# WindGustSpeed      19.000000
# WindDir9am          8.000000
# WindDir3pm          8.000000
# WindSpeed9am       11.000000
# WindSpeed3pm       13.000000
# Humidity9am        26.660199
# Humidity3pm        30.000000
# Pressure9am         9.000000
# Pressure3pm         9.000000
# Cloud9am            4.000000
# Cloud3pm            3.662938
# Temp9am             9.400000
# Temp3pm            10.100000
# RainToday           1.000000
# RISK_MM             5.000000
# RainTomorrow        1.000000
# dtype: float64

# %%
# Removing outliers from dataset
MiceImputed = MiceImputed[~((MiceImputed < (Q1 - 1.5 * IQR)) |(MiceImputed > (Q3 + 1.5 * IQR))).any(axis=1)]
MiceImputed.shape
# Out:
# (134611, 24)
