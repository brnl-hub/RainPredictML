# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("Weather.csv")
data.head()
# Out:
#        Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 0  01-02-13     20.7     20.9     19.5     22.4      15.6       Yes
# 1  02-02-13     22.4     24.8     19.5     25.6       6.0       Yes
# 2  03-02-13     23.5     23.0     21.6     24.5       6.6       Yes
# 3  04-02-13     21.4     20.9     20.2     22.8      18.8       Yes
# 4  05-02-13     22.5     25.5     19.7     25.7      77.4       Yes
#
#    Evaporation  Sunshine WindGustDir  ...  WindDir9am WindDir3pm WindSpeed9am  \
# 0          6.2       0.0           W  ...           S        SSW           17
# 1          3.4       2.7           W  ...           W          E            9
# 2          2.4       0.1           W  ...         ESE        ESE           17
# 3          2.2       0.0           W  ...         NNE          E           22
# 4          4.8       0.0           W  ...         NNE          W           11
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# ...

# %%
data.tail()
# Out:
#           Date  Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  \
# 3266  11-01-22     10.5     17.9      8.6     19.6       0.0        No
# 3267  12-01-22     11.0     18.7      9.3     19.2       0.0        No
# 3268  13-01-22     10.2     17.3      9.4     17.7       0.0        No
# 3269  14-01-22     12.4     19.0     10.1     19.3       0.0        No
# 3270  15-01-22      9.4     18.8      7.6     19.3       0.0        No
#
#       Evaporation  Sunshine WindGustDir  ...  WindDir9am WindDir3pm  \
# 3266          2.0       7.8         SSE  ...           W        SSE
# 3267          2.0       9.2           W  ...           W        ESE
# 3268          2.4       2.7           W  ...         WNW          N
# 3269          1.4       9.3           W  ...           W          W
# 3270          3.4       9.4           W  ...           W          W
#
#      WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
data.shape
# Out:
# (3271, 21)

# %%
print("Data info : ")
data.info()
# Out:
# Data info :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   object
#  1   Temp9am        3271 non-null   float64
#  2   Temp3pm        3271 non-null   float64
#  3   MinTemp        3271 non-null   float64
#  4   MaxTemp        3271 non-null   float64
#  5   Rainfall       3271 non-null   float64
#  6   RainToday      3271 non-null   object
#  7   Evaporation    3271 non-null   float64
#  8   Sunshine       3271 non-null   float64
#  9   WindGustDir    3271 non-null   object
#  10  WindGustSpeed  3271 non-null   int64
#  11  WindDir9am     3271 non-null   object
#  12  WindDir3pm     3271 non-null   object
#  13  WindSpeed9am   3271 non-null   int64
#  14  WindSpeed3pm   3271 non-null   int64
#  15  Humidity9am    3271 non-null   int64
#  16  Humidity3pm    3271 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Temp9am', 'Temp3pm', 'MinTemp', 'MaxTemp', 'Rainfall',
#        'RainToday', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am',
#        'Cloud3pm'],
#       dtype='object')

# %%
data = data.drop(columns=["Date"])

# %%
data.head()
# Out:
#    Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall RainToday  Evaporation  \
# 0     20.7     20.9     19.5     22.4      15.6       Yes          6.2
# 1     22.4     24.8     19.5     25.6       6.0       Yes          3.4
# 2     23.5     23.0     21.6     24.5       6.6       Yes          2.4
# 3     21.4     20.9     20.2     22.8      18.8       Yes          2.2
# 4     22.5     25.5     19.7     25.7      77.4       Yes          4.8
#
#    Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0       0.0           W             41          S        SSW            17
# 1       2.7           W             41          W          E             9
# 2       0.1           W             41        ESE        ESE            17
# 3       0.0           W             41        NNE          E            22
# 4       0.0           W             41        NNE          W            11
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# ...

# %%
data.isnull().sum()
# Out:
# Temp9am          0
# Temp3pm          0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# RainToday        0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# dtype: int64

# %%
data["RainToday"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data["RainToday"]=data["RainToday"].replace({"Yes":1, "No":0})
# Out:
# C:\Users\gogoi\AppData\Local\Temp\ipykernel_13620\369962909.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["RainToday"]=data["RainToday"].replace({"Yes":1, "No":0})

# %%
data.head()
# Out:
#    Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall  RainToday  Evaporation  \
# 0     20.7     20.9     19.5     22.4      15.6          1          6.2
# 1     22.4     24.8     19.5     25.6       6.0          1          3.4
# 2     23.5     23.0     21.6     24.5       6.6          1          2.4
# 3     21.4     20.9     20.2     22.8      18.8          1          2.2
# 4     22.5     25.5     19.7     25.7      77.4          1          4.8
#
#    Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0       0.0           W             41          S        SSW            17
# 1       2.7           W             41          W          E             9
# 2       0.1           W             41        ESE        ESE            17
# 3       0.0           W             41        NNE          E            22
# 4       0.0           W             41        NNE          W            11
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# ...

# %%
data["WindGustDir"].unique()
# Out:
# array(['W', 'NNW', 'WNW', 'ENE', 'NNE', 'NW', 'SSE', 'NE', 'ESE', 'WSW',
#        'SE', 'SW', 'N', 'E', 'SSW', 'S'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(data["WindGustDir"])
# Out:
# LabelEncoder()

# %%
data["WindGustDir"]=le.transform(data["WindGustDir"])

# %%
data.head()
# Out:
#    Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall  RainToday  Evaporation  \
# 0     20.7     20.9     19.5     22.4      15.6          1          6.2
# 1     22.4     24.8     19.5     25.6       6.0          1          3.4
# 2     23.5     23.0     21.6     24.5       6.6          1          2.4
# 3     21.4     20.9     20.2     22.8      18.8          1          2.2
# 4     22.5     25.5     19.7     25.7      77.4          1          4.8
#
#    Sunshine  WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0       0.0           13             41          S        SSW            17
# 1       2.7           13             41          W          E             9
# 2       0.1           13             41        ESE        ESE            17
# 3       0.0           13             41        NNE          E            22
# 4       0.0           13             41        NNE          W            11
#
# ...

# %%
data["WindDir9am"].unique()
# Out:
# array(['S', 'W', 'ESE', 'NNE', 'SSW', 'WNW', 'N', 'SW', 'SE', 'SSE',
#        'WSW', 'E', 'ENE', 'NW', 'NNW', 'NE'], dtype=object)

# %%
le.fit(data["WindDir9am"])
data["WindDir9am"]=le.transform(data["WindDir9am"])

le.fit(data["WindDir3pm"])
data["WindDir3pm"]=le.transform(data["WindDir3pm"])

# %%
data.head()
# Out:
#    Temp9am  Temp3pm  MinTemp  MaxTemp  Rainfall  RainToday  Evaporation  \
# 0     20.7     20.9     19.5     22.4      15.6          1          6.2
# 1     22.4     24.8     19.5     25.6       6.0          1          3.4
# 2     23.5     23.0     21.6     24.5       6.6          1          2.4
# 3     21.4     20.9     20.2     22.8      18.8          1          2.2
# 4     22.5     25.5     19.7     25.7      77.4          1          4.8
#
#    Sunshine  WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 0       0.0           13             41           8          11            17
# 1       2.7           13             41          13           0             9
# 2       0.1           13             41           2           2            17
# 3       0.0           13             41           5           0            22
# 4       0.0           13             41           5          13            11
#
# ...

# %%
#data analysis
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")
data.describe()
# Out:
#            Temp9am      Temp3pm      MinTemp      MaxTemp     Rainfall  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     17.821461    21.543656    14.877102    23.005564     3.342158
# std       4.894316     4.297053     4.554710     4.483752     9.917746
# min       6.400000    10.200000     4.300000    11.700000     0.000000
# 25%      13.800000    18.400000    11.000000    19.600000     0.000000
# 50%      18.200000    21.300000    14.900000    22.800000     0.000000
# 75%      21.700000    24.500000    18.800000    26.000000     1.400000
# max      36.500000    44.700000    27.600000    45.800000   119.400000
#
#          RainToday  Evaporation     Sunshine  WindGustDir  WindGustSpeed  \
# count  3271.000000  3271.000000  3271.000000  3271.000000    3271.000000
# mean      0.259554     5.175787     7.168970     9.532559      41.476307
# std       0.438457     2.757684     3.815966     4.595180      10.806951
# ...

# %%
plt.Figure(figsize=(6,4))
sns.countplot(x="RainToday", data = data)
plt.title("Distribution of RainToday")
plt.show()

# %%
#correlation
correlation_matrix = data.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.show()

# %%
#drop highly correlated colums
#drop highly correlated colums
data = data.drop(columns=['Temp9am','Temp3pm','MinTemp'])

# %%
data.head()
# Out:
#    MaxTemp  Rainfall  RainToday  Evaporation  Sunshine  WindGustDir  \
# 0     22.4      15.6          1          6.2       0.0           13
# 1     25.6       6.0          1          3.4       2.7           13
# 2     24.5       6.6          1          2.4       0.1           13
# 3     22.8      18.8          1          2.2       0.0           13
# 4     25.7      77.4          1          4.8       0.0           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0             41           8          11            17            20
# 1             41          13           0             9            13
# 2             41           2           2            17             2
# 3             41           5           0            22            20
# 4             41           5          13            11             6
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm
# ...

# %%
data.shape
# Out:
# (3271, 17)

# %%
#now handle class imbalance
plt.Figure(figsize=(6,4))
sns.countplot(x="RainToday", data = data)
plt.title("Distribution of RainToday")
plt.show()

# %%
data["RainToday"].value_counts()
# Out:
# RainToday
# 0    2422
# 1     849
# Name: count, dtype: int64

# %%
#so the majority class is 0 and minority class is 1 now separate data


from sklearn.utils import resample

no = data[data.RainToday == 0]
yes = data[data.RainToday == 1]
yes_oversampled = resample(yes, replace=True, n_samples=len(no), random_state=123)
oversampled = pd.concat([no, yes_oversampled])

fig = plt.figure(figsize = (8,5))
oversampled.RainToday.value_counts(normalize = True).plot(kind='bar', color= ['skyblue','navy'], alpha = 0.9, rot=0)
plt.title('RainToday Indicator No(0) and Yes(1) after Oversampling (Balanced Dataset)')
plt.show()

# %%
#Split featres and target as x and y 
x = data.drop(columns=['RainToday'])
y = data['RainToday']

# %%
print(x)
# Out:
#       MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  WindGustSpeed  \
# 0        22.4      15.6          6.2       0.0           13             41
# 1        25.6       6.0          3.4       2.7           13             41
# 2        24.5       6.6          2.4       0.1           13             41
# 3        22.8      18.8          2.2       0.0           13             41
# 4        25.7      77.4          4.8       0.0           13             41
# ...       ...       ...          ...       ...          ...            ...
# 3266     19.6       0.0          2.0       7.8           10             37
# 3267     19.2       0.0          2.0       9.2           13             30
# 3268     17.7       0.0          2.4       2.7           13             24
# 3269     19.3       0.0          1.4       9.3           13             43
# 3270     19.3       0.0          3.4       9.4           13             35
#
# ...

# %%
print(y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3266    0
# 3267    0
# 3268    0
# 3269    0
# 3270    0
# Name: RainToday, Length: 3271, dtype: int64

# %%
#split the data into train and test data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
len(x_test)
# Out:
# 655

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,3))
sns.scatterplot(x='Rainfall',y='RainToday', data=data)
plt.show()

# %%
numeric_cols = data.select_dtypes(include='number').columns

plt.figure(figsize=(5, 3 * len(numeric_cols)))

for i, column in enumerate(numeric_cols):
    plt.subplot(len(numeric_cols), 1, i + 1)
    sns.histplot(data[column], kde=True)
    plt.title(f"Distribution of {column}")

plt.tight_layout()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
model.score(x_test,y_test)
# Out:
# 0.8259541984732824

# %%
#Confusion matrix
y_predict = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[447,  29],
#        [ 85,  94]])

# %%
# %matplotlib inline
plt.Figure(figsize=(10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('real')
# Out:
# Text(47.25, 0.5, 'real')
